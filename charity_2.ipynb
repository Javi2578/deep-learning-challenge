# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df_dropped = application_df.drop(['EIN', 'NAME'], axis=1)
df_dropped.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.

unique_values = df_dropped.nunique()

# Display the number of unique values for each column
unique_values
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = df_dropped['APPLICATION_TYPE'].value_counts()
# Display the value counts for APPLICATION_TYPE
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = df_dropped['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 1000
classifications_to_replace = classification_counts[classification_counts < cutoff_value].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# @title Default title text
# Convert categorical data to numeric with `pd.get_dummies`
df_dummies = pd.get_dummies(df_dropped)

# Display the first few rows of the dataframe with dummies to confirm the conversion
df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# 0                     0                     0  ...                  0
# 1                     0                     0  ...                  1
# 2                     0                     0  ...                  0
# 3                     0                     0  ...                  0
# 4                     0                     0  ...                  0
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                       0                         0                   0
# 1                       0                         0                   0
# 2                       0                         0                   0
# 3                       1                         0                   0
# 4                       0                         1                   0
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                 0                       0                0
# 1                 0                       0                0
# 2                 0                       0                0
# 3                 0                       0                0
# 4                 0                       0                0
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                  0                         1                         0
# 1                  0                         1                         0
# 2                  0                         1                         0
# 3                  0                         1                         0
# 4                  0                         1                         0
#
# [5 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
# use get dummies
X = df_dummies.drop(["IS_SUCCESSFUL"], axis='columns').values
y = df_dummies["IS_SUCCESSFUL"].values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, input_dim=len(X_train_scaled[0]), activation="relu"),
    tf.keras.layers.Dense(80, activation="relu"),
     tf.keras.layers.Dense(40, activation="relu"),
    tf.keras.layers.Dense(1, activation ="sigmoid")
])

# Train the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train_scaled, y_train,
    epochs=100,  # Number of epochs to train for
    batch_size=256,  # Batch size for training
    validation_split=0.2,  # Fraction of training data to use for validation
    verbose=1  # Show training log
)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 3s 12ms/step - loss: 0.5865 - accuracy: 0.7184 - val_loss: 0.5648 - val_accuracy: 0.7224
# Epoch 2/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5510 - accuracy: 0.7332 - val_loss: 0.5627 - val_accuracy: 0.7226
# Epoch 3/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5469 - accuracy: 0.7359 - val_loss: 0.5653 - val_accuracy: 0.7215
# Epoch 4/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5448 - accuracy: 0.7366 - val_loss: 0.5672 - val_accuracy: 0.7234
# Epoch 5/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.5421 - accuracy: 0.7360 - val_loss: 0.5632 - val_accuracy: 0.7230
# Epoch 6/100
# 81/81 [==============================] - 1s 12ms/step - loss: 0.5409 - accuracy: 0.7366 - val_loss: 0.5634 - val_accuracy: 0.7219
# Epoch 7/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5408 - accuracy: 0.7396 - val_loss: 0.5611 - val_accuracy: 0.7234
# Epoch 8/100
# 81/81 [==============================] - 1s 12ms/step - loss: 0.5379 - accuracy: 0.7394 - val_loss: 0.5630 - val_accuracy: 0.7259
# Epoch 9/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.5373 - accuracy: 0.7400 - val_loss: 0.5622 - val_accuracy: 0.7228
# Epoch 10/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5370 - accuracy: 0.7393 - val_loss: 0.5623 - val_accuracy: 0.7228
# Epoch 11/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5363 - accuracy: 0.7404 - val_loss: 0.5627 - val_accuracy: 0.7242
# Epoch 12/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5352 - accuracy: 0.7406 - val_loss: 0.5631 - val_accuracy: 0.7221
# Epoch 13/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5345 - accuracy: 0.7414 - val_loss: 0.5633 - val_accuracy: 0.7261
# Epoch 14/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5358 - accuracy: 0.7410 - val_loss: 0.5654 - val_accuracy: 0.7238
# Epoch 15/100
# 81/81 [==============================] - 2s 22ms/step - loss: 0.5352 - accuracy: 0.7412 - val_loss: 0.5633 - val_accuracy: 0.7250
# Epoch 16/100
# 81/81 [==============================] - 1s 17ms/step - loss: 0.5336 - accuracy: 0.7424 - val_loss: 0.5674 - val_accuracy: 0.7263
# Epoch 17/100
# 81/81 [==============================] - 2s 19ms/step - loss: 0.5335 - accuracy: 0.7414 - val_loss: 0.5625 - val_accuracy: 0.7226
# Epoch 18/100
# 81/81 [==============================] - 1s 15ms/step - loss: 0.5336 - accuracy: 0.7411 - val_loss: 0.5655 - val_accuracy: 0.7252
# Epoch 19/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5330 - accuracy: 0.7405 - val_loss: 0.5622 - val_accuracy: 0.7232
# Epoch 20/100
# 81/81 [==============================] - 1s 11ms/step - loss: 0.5328 - accuracy: 0.7429 - val_loss: 0.5656 - val_accuracy: 0.7234
# Epoch 21/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5320 - accuracy: 0.7426 - val_loss: 0.5674 - val_accuracy: 0.7217
# Epoch 22/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5315 - accuracy: 0.7427 - val_loss: 0.5621 - val_accuracy: 0.7256
# Epoch 23/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5308 - accuracy: 0.7435 - val_loss: 0.5657 - val_accuracy: 0.7234
# Epoch 24/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5312 - accuracy: 0.7427 - val_loss: 0.5677 - val_accuracy: 0.7215
# Epoch 25/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5325 - accuracy: 0.7430 - val_loss: 0.5662 - val_accuracy: 0.7256
# Epoch 26/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5310 - accuracy: 0.7438 - val_loss: 0.5646 - val_accuracy: 0.7232
# Epoch 27/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5301 - accuracy: 0.7443 - val_loss: 0.5661 - val_accuracy: 0.7232
# Epoch 28/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5305 - accuracy: 0.7433 - val_loss: 0.5663 - val_accuracy: 0.7265
# Epoch 29/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5298 - accuracy: 0.7437 - val_loss: 0.5670 - val_accuracy: 0.7230
# Epoch 30/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5302 - accuracy: 0.7442 - val_loss: 0.5660 - val_accuracy: 0.7254
# Epoch 31/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5302 - accuracy: 0.7446 - val_loss: 0.5731 - val_accuracy: 0.7232
# Epoch 32/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5307 - accuracy: 0.7427 - val_loss: 0.5675 - val_accuracy: 0.7221
# Epoch 33/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5293 - accuracy: 0.7445 - val_loss: 0.5648 - val_accuracy: 0.7219
# Epoch 34/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5296 - accuracy: 0.7427 - val_loss: 0.5696 - val_accuracy: 0.7261
# Epoch 35/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5297 - accuracy: 0.7447 - val_loss: 0.5654 - val_accuracy: 0.7267
# Epoch 36/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5288 - accuracy: 0.7438 - val_loss: 0.5675 - val_accuracy: 0.7213
# Epoch 37/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5288 - accuracy: 0.7451 - val_loss: 0.5699 - val_accuracy: 0.7273
# Epoch 38/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5285 - accuracy: 0.7443 - val_loss: 0.5643 - val_accuracy: 0.7263
# Epoch 39/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5286 - accuracy: 0.7448 - val_loss: 0.5646 - val_accuracy: 0.7254
# Epoch 40/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5282 - accuracy: 0.7454 - val_loss: 0.5682 - val_accuracy: 0.7250
# Epoch 41/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5286 - accuracy: 0.7444 - val_loss: 0.5666 - val_accuracy: 0.7246
# Epoch 42/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5283 - accuracy: 0.7447 - val_loss: 0.5676 - val_accuracy: 0.7265
# Epoch 43/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5283 - accuracy: 0.7445 - val_loss: 0.5691 - val_accuracy: 0.7254
# Epoch 44/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5281 - accuracy: 0.7457 - val_loss: 0.5691 - val_accuracy: 0.7215
# Epoch 45/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5283 - accuracy: 0.7451 - val_loss: 0.5683 - val_accuracy: 0.7261
# Epoch 46/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5279 - accuracy: 0.7443 - val_loss: 0.5665 - val_accuracy: 0.7265
# Epoch 47/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5273 - accuracy: 0.7458 - val_loss: 0.5698 - val_accuracy: 0.7250
# Epoch 48/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5274 - accuracy: 0.7455 - val_loss: 0.5680 - val_accuracy: 0.7256
# Epoch 49/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5279 - accuracy: 0.7448 - val_loss: 0.5706 - val_accuracy: 0.7263
# Epoch 50/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5280 - accuracy: 0.7440 - val_loss: 0.5703 - val_accuracy: 0.7259
# Epoch 51/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5270 - accuracy: 0.7465 - val_loss: 0.5683 - val_accuracy: 0.7248
# Epoch 52/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5271 - accuracy: 0.7461 - val_loss: 0.5697 - val_accuracy: 0.7250
# Epoch 53/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5269 - accuracy: 0.7458 - val_loss: 0.5706 - val_accuracy: 0.7279
# Epoch 54/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5273 - accuracy: 0.7453 - val_loss: 0.5687 - val_accuracy: 0.7256
# Epoch 55/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5268 - accuracy: 0.7461 - val_loss: 0.5697 - val_accuracy: 0.7258
# Epoch 56/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7451 - val_loss: 0.5697 - val_accuracy: 0.7248
# Epoch 57/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5268 - accuracy: 0.7450 - val_loss: 0.5713 - val_accuracy: 0.7244
# Epoch 58/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5278 - accuracy: 0.7451 - val_loss: 0.5687 - val_accuracy: 0.7273
# Epoch 59/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5264 - accuracy: 0.7454 - val_loss: 0.5695 - val_accuracy: 0.7265
# Epoch 60/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5266 - accuracy: 0.7459 - val_loss: 0.5731 - val_accuracy: 0.7246
# Epoch 61/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7454 - val_loss: 0.5693 - val_accuracy: 0.7254
# Epoch 62/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5264 - accuracy: 0.7460 - val_loss: 0.5706 - val_accuracy: 0.7228
# Epoch 63/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5261 - accuracy: 0.7463 - val_loss: 0.5711 - val_accuracy: 0.7254
# Epoch 64/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5263 - accuracy: 0.7463 - val_loss: 0.5723 - val_accuracy: 0.7252
# Epoch 65/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5262 - accuracy: 0.7454 - val_loss: 0.5741 - val_accuracy: 0.7256
# Epoch 66/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5264 - accuracy: 0.7454 - val_loss: 0.5689 - val_accuracy: 0.7256
# Epoch 67/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5257 - accuracy: 0.7463 - val_loss: 0.5694 - val_accuracy: 0.7267
# Epoch 68/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7467 - val_loss: 0.5726 - val_accuracy: 0.7261
# Epoch 69/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5262 - accuracy: 0.7457 - val_loss: 0.5721 - val_accuracy: 0.7259
# Epoch 70/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5256 - accuracy: 0.7462 - val_loss: 0.5715 - val_accuracy: 0.7242
# Epoch 71/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5259 - accuracy: 0.7461 - val_loss: 0.5727 - val_accuracy: 0.7256
# Epoch 72/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5252 - accuracy: 0.7469 - val_loss: 0.5747 - val_accuracy: 0.7244
# Epoch 73/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5260 - accuracy: 0.7459 - val_loss: 0.5723 - val_accuracy: 0.7289
# Epoch 74/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5255 - accuracy: 0.7451 - val_loss: 0.5767 - val_accuracy: 0.7269
# Epoch 75/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5256 - accuracy: 0.7461 - val_loss: 0.5730 - val_accuracy: 0.7261
# Epoch 76/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5253 - accuracy: 0.7459 - val_loss: 0.5752 - val_accuracy: 0.7287
# Epoch 77/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5252 - accuracy: 0.7459 - val_loss: 0.5758 - val_accuracy: 0.7246
# Epoch 78/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5252 - accuracy: 0.7471 - val_loss: 0.5754 - val_accuracy: 0.7248
# Epoch 79/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5254 - accuracy: 0.7453 - val_loss: 0.5733 - val_accuracy: 0.7269
# Epoch 80/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5250 - accuracy: 0.7463 - val_loss: 0.5748 - val_accuracy: 0.7261
# Epoch 81/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5250 - accuracy: 0.7452 - val_loss: 0.5765 - val_accuracy: 0.7275
# Epoch 82/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.7457 - val_loss: 0.5751 - val_accuracy: 0.7242
# Epoch 83/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.7459 - val_loss: 0.5744 - val_accuracy: 0.7250
# Epoch 84/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5243 - accuracy: 0.7464 - val_loss: 0.5767 - val_accuracy: 0.7277
# Epoch 85/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5249 - accuracy: 0.7457 - val_loss: 0.5810 - val_accuracy: 0.7224
# Epoch 86/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5252 - accuracy: 0.7461 - val_loss: 0.5744 - val_accuracy: 0.7248
# Epoch 87/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.7463 - val_loss: 0.5767 - val_accuracy: 0.7252
# Epoch 88/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5248 - accuracy: 0.7461 - val_loss: 0.5756 - val_accuracy: 0.7267
# Epoch 89/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5249 - accuracy: 0.7458 - val_loss: 0.5764 - val_accuracy: 0.7277
# Epoch 90/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5253 - accuracy: 0.7451 - val_loss: 0.5801 - val_accuracy: 0.7234
# Epoch 91/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5242 - accuracy: 0.7461 - val_loss: 0.5782 - val_accuracy: 0.7267
# Epoch 92/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5249 - accuracy: 0.7464 - val_loss: 0.5768 - val_accuracy: 0.7256
# Epoch 93/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5246 - accuracy: 0.7461 - val_loss: 0.5788 - val_accuracy: 0.7246
# Epoch 94/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5241 - accuracy: 0.7460 - val_loss: 0.5780 - val_accuracy: 0.7246
# Epoch 95/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5244 - accuracy: 0.7471 - val_loss: 0.5808 - val_accuracy: 0.7277
# Epoch 96/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5245 - accuracy: 0.7459 - val_loss: 0.5771 - val_accuracy: 0.7265
# Epoch 97/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5243 - accuracy: 0.7460 - val_loss: 0.5786 - val_accuracy: 0.7254
# Epoch 98/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5242 - accuracy: 0.7461 - val_loss: 0.5789 - val_accuracy: 0.7242
# Epoch 99/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5242 - accuracy: 0.7456 - val_loss: 0.5809 - val_accuracy: 0.7254
# Epoch 100/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5234 - accuracy: 0.7454 - val_loss: 0.5838 - val_accuracy: 0.7263

# %%
# Evaluate the model using the test data
test_loss, test_mae = model.evaluate(X_test_scaled, y_test)
print("Test loss:", test_loss)
print("Test MAE:", test_mae)
# Out:
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5626 - accuracy: 0.7285
# Test loss: 0.5626207590103149
# Test MAE: 0.7285131216049194

# %%
# Export our model to HDF5 file
model.save('/content/drive/MyDrive/Colab Notebooks/charity_2.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
