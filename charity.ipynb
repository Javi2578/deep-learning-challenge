# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
df_dropped = application_df.drop(['EIN', 'NAME'], axis=1)
df_dropped.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.

unique_values = df_dropped.nunique()

# Display the number of unique values for each column
unique_values
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = df_dropped['APPLICATION_TYPE'].value_counts()
# Display the value counts for APPLICATION_TYPE
application_type_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 500
application_types_to_replace = application_type_counts[application_type_counts < cutoff_value].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = df_dropped['CLASSIFICATION'].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 1000
classifications_to_replace = classification_counts[classification_counts < cutoff_value].index.tolist()
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# @title Default title text
# Convert categorical data to numeric with `pd.get_dummies`
df_dummies = pd.get_dummies(df_dropped)

# Display the first few rows of the dataframe with dummies to confirm the conversion
df_dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_T10  APPLICATION_TYPE_T12  \
# 0       1     5000              1                     1                     0
# 1       1   108590              1                     0                     0
# 2       1     5000              0                     0                     0
# 3       1     6692              1                     0                     0
# 4       1   142590              1                     0                     0
#
#    APPLICATION_TYPE_T13  APPLICATION_TYPE_T14  APPLICATION_TYPE_T15  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    APPLICATION_TYPE_T17  APPLICATION_TYPE_T19  ...  INCOME_AMT_1-9999  \
# 0                     0                     0  ...                  0
# 1                     0                     0  ...                  1
# 2                     0                     0  ...                  0
# 3                     0                     0  ...                  0
# 4                     0                     0  ...                  0
#
#    INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  \
# 0                       0                         0                   0
# 1                       0                         0                   0
# 2                       0                         0                   0
# 3                       1                         0                   0
# 4                       0                         1                   0
#
#    INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  INCOME_AMT_50M+  \
# 0                 0                       0                0
# 1                 0                       0                0
# 2                 0                       0                0
# 3                 0                       0                0
# 4                 0                       0                0
#
#    INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0                  0                         1                         0
# 1                  0                         1                         0
# 2                  0                         1                         0
# 3                  0                         1                         0
# 4                  0                         1                         0
#
# [5 rows x 117 columns]

# %%
# Split our preprocessed data into our features and target arrays
# use get dummies
X = df_dummies.drop(["IS_SUCCESSFUL"], axis='columns').values
y = df_dummies["IS_SUCCESSFUL"].values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, input_dim=len(X_train_scaled[0]), activation="relu"),
    tf.keras.layers.Dense(60, activation="relu"),
    tf.keras.layers.Dense(1, activation ="sigmoid")
])

# Train the model
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
model.fit(X_train_scaled, y_train,
    epochs=100,  # Number of epochs to train for
    batch_size=256,  # Batch size for training
    validation_split=0.2,  # Fraction of training data to use for validation
    verbose=1  # Show training log
)
# Out:
# Epoch 1/100
# 81/81 [==============================] - 4s 12ms/step - loss: 0.5976 - accuracy: 0.7039 - val_loss: 0.5697 - val_accuracy: 0.7213
# Epoch 2/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5548 - accuracy: 0.7323 - val_loss: 0.5652 - val_accuracy: 0.7223
# Epoch 3/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5479 - accuracy: 0.7353 - val_loss: 0.5631 - val_accuracy: 0.7221
# Epoch 4/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5458 - accuracy: 0.7351 - val_loss: 0.5626 - val_accuracy: 0.7238
# Epoch 5/100
# 81/81 [==============================] - 1s 15ms/step - loss: 0.5436 - accuracy: 0.7365 - val_loss: 0.5619 - val_accuracy: 0.7240
# Epoch 6/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5430 - accuracy: 0.7356 - val_loss: 0.5625 - val_accuracy: 0.7244
# Epoch 7/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5416 - accuracy: 0.7373 - val_loss: 0.5617 - val_accuracy: 0.7279
# Epoch 8/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5408 - accuracy: 0.7371 - val_loss: 0.5622 - val_accuracy: 0.7254
# Epoch 9/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5396 - accuracy: 0.7382 - val_loss: 0.5622 - val_accuracy: 0.7261
# Epoch 10/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5387 - accuracy: 0.7380 - val_loss: 0.5628 - val_accuracy: 0.7232
# Epoch 11/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5382 - accuracy: 0.7388 - val_loss: 0.5635 - val_accuracy: 0.7244
# Epoch 12/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5388 - accuracy: 0.7388 - val_loss: 0.5631 - val_accuracy: 0.7240
# Epoch 13/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5373 - accuracy: 0.7392 - val_loss: 0.5638 - val_accuracy: 0.7221
# Epoch 14/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5369 - accuracy: 0.7390 - val_loss: 0.5624 - val_accuracy: 0.7248
# Epoch 15/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5368 - accuracy: 0.7401 - val_loss: 0.5632 - val_accuracy: 0.7242
# Epoch 16/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5362 - accuracy: 0.7402 - val_loss: 0.5631 - val_accuracy: 0.7228
# Epoch 17/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5354 - accuracy: 0.7408 - val_loss: 0.5639 - val_accuracy: 0.7226
# Epoch 18/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5355 - accuracy: 0.7400 - val_loss: 0.5630 - val_accuracy: 0.7234
# Epoch 19/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5348 - accuracy: 0.7409 - val_loss: 0.5627 - val_accuracy: 0.7238
# Epoch 20/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5357 - accuracy: 0.7404 - val_loss: 0.5638 - val_accuracy: 0.7238
# Epoch 21/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5348 - accuracy: 0.7396 - val_loss: 0.5665 - val_accuracy: 0.7188
# Epoch 22/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5343 - accuracy: 0.7414 - val_loss: 0.5642 - val_accuracy: 0.7240
# Epoch 23/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5347 - accuracy: 0.7408 - val_loss: 0.5639 - val_accuracy: 0.7246
# Epoch 24/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5350 - accuracy: 0.7419 - val_loss: 0.5636 - val_accuracy: 0.7256
# Epoch 25/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5331 - accuracy: 0.7422 - val_loss: 0.5652 - val_accuracy: 0.7271
# Epoch 26/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5338 - accuracy: 0.7419 - val_loss: 0.5668 - val_accuracy: 0.7238
# Epoch 27/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5336 - accuracy: 0.7412 - val_loss: 0.5654 - val_accuracy: 0.7219
# Epoch 28/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5329 - accuracy: 0.7429 - val_loss: 0.5641 - val_accuracy: 0.7230
# Epoch 29/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5325 - accuracy: 0.7430 - val_loss: 0.5640 - val_accuracy: 0.7228
# Epoch 30/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5319 - accuracy: 0.7425 - val_loss: 0.5649 - val_accuracy: 0.7228
# Epoch 31/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5326 - accuracy: 0.7424 - val_loss: 0.5632 - val_accuracy: 0.7211
# Epoch 32/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5317 - accuracy: 0.7423 - val_loss: 0.5655 - val_accuracy: 0.7236
# Epoch 33/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5324 - accuracy: 0.7433 - val_loss: 0.5650 - val_accuracy: 0.7246
# Epoch 34/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5324 - accuracy: 0.7422 - val_loss: 0.5664 - val_accuracy: 0.7240
# Epoch 35/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5322 - accuracy: 0.7426 - val_loss: 0.5681 - val_accuracy: 0.7240
# Epoch 36/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5317 - accuracy: 0.7409 - val_loss: 0.5651 - val_accuracy: 0.7246
# Epoch 37/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5317 - accuracy: 0.7432 - val_loss: 0.5629 - val_accuracy: 0.7246
# Epoch 38/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5312 - accuracy: 0.7428 - val_loss: 0.5652 - val_accuracy: 0.7242
# Epoch 39/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5316 - accuracy: 0.7427 - val_loss: 0.5646 - val_accuracy: 0.7230
# Epoch 40/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5317 - accuracy: 0.7440 - val_loss: 0.5644 - val_accuracy: 0.7234
# Epoch 41/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5307 - accuracy: 0.7434 - val_loss: 0.5644 - val_accuracy: 0.7238
# Epoch 42/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5303 - accuracy: 0.7444 - val_loss: 0.5656 - val_accuracy: 0.7248
# Epoch 43/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5310 - accuracy: 0.7438 - val_loss: 0.5621 - val_accuracy: 0.7254
# Epoch 44/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5306 - accuracy: 0.7454 - val_loss: 0.5644 - val_accuracy: 0.7252
# Epoch 45/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5302 - accuracy: 0.7443 - val_loss: 0.5642 - val_accuracy: 0.7256
# Epoch 46/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5309 - accuracy: 0.7433 - val_loss: 0.5667 - val_accuracy: 0.7234
# Epoch 47/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5304 - accuracy: 0.7447 - val_loss: 0.5664 - val_accuracy: 0.7234
# Epoch 48/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.7448 - val_loss: 0.5670 - val_accuracy: 0.7254
# Epoch 49/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5298 - accuracy: 0.7453 - val_loss: 0.5666 - val_accuracy: 0.7238
# Epoch 50/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5300 - accuracy: 0.7451 - val_loss: 0.5654 - val_accuracy: 0.7252
# Epoch 51/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5295 - accuracy: 0.7441 - val_loss: 0.5654 - val_accuracy: 0.7261
# Epoch 52/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5297 - accuracy: 0.7445 - val_loss: 0.5656 - val_accuracy: 0.7250
# Epoch 53/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5296 - accuracy: 0.7446 - val_loss: 0.5678 - val_accuracy: 0.7242
# Epoch 54/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5292 - accuracy: 0.7441 - val_loss: 0.5663 - val_accuracy: 0.7242
# Epoch 55/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5298 - accuracy: 0.7450 - val_loss: 0.5675 - val_accuracy: 0.7252
# Epoch 56/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5292 - accuracy: 0.7445 - val_loss: 0.5669 - val_accuracy: 0.7248
# Epoch 57/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5293 - accuracy: 0.7443 - val_loss: 0.5676 - val_accuracy: 0.7252
# Epoch 58/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5292 - accuracy: 0.7442 - val_loss: 0.5657 - val_accuracy: 0.7242
# Epoch 59/100
# 81/81 [==============================] - 1s 10ms/step - loss: 0.5286 - accuracy: 0.7452 - val_loss: 0.5667 - val_accuracy: 0.7226
# Epoch 60/100
# 81/81 [==============================] - 1s 8ms/step - loss: 0.5284 - accuracy: 0.7445 - val_loss: 0.5676 - val_accuracy: 0.7240
# Epoch 61/100
# 81/81 [==============================] - 1s 9ms/step - loss: 0.5289 - accuracy: 0.7446 - val_loss: 0.5668 - val_accuracy: 0.7223
# Epoch 62/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5288 - accuracy: 0.7442 - val_loss: 0.5681 - val_accuracy: 0.7240
# Epoch 63/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5283 - accuracy: 0.7447 - val_loss: 0.5682 - val_accuracy: 0.7250
# Epoch 64/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5286 - accuracy: 0.7450 - val_loss: 0.5697 - val_accuracy: 0.7230
# Epoch 65/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5284 - accuracy: 0.7439 - val_loss: 0.5667 - val_accuracy: 0.7248
# Epoch 66/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5284 - accuracy: 0.7451 - val_loss: 0.5693 - val_accuracy: 0.7234
# Epoch 67/100
# 81/81 [==============================] - 1s 7ms/step - loss: 0.5279 - accuracy: 0.7436 - val_loss: 0.5684 - val_accuracy: 0.7252
# Epoch 68/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5275 - accuracy: 0.7449 - val_loss: 0.5687 - val_accuracy: 0.7234
# Epoch 69/100
# 81/81 [==============================] - 1s 6ms/step - loss: 0.5279 - accuracy: 0.7452 - val_loss: 0.5681 - val_accuracy: 0.7242
# Epoch 70/100
# 81/81 [==============================] - 0s 6ms/step - loss: 0.5277 - accuracy: 0.7464 - val_loss: 0.5670 - val_accuracy: 0.7244
# Epoch 71/100
# 81/81 [==============================] - 0s 5ms/step - loss: 0.5279 - accuracy: 0.7442 - val_loss: 0.5705 - val_accuracy: 0.7234
# Epoch 72/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.7450 - val_loss: 0.5705 - val_accuracy: 0.7254
# Epoch 73/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5277 - accuracy: 0.7453 - val_loss: 0.5704 - val_accuracy: 0.7240
# Epoch 74/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5274 - accuracy: 0.7455 - val_loss: 0.5687 - val_accuracy: 0.7254
# Epoch 75/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7456 - val_loss: 0.5683 - val_accuracy: 0.7258
# Epoch 76/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5269 - accuracy: 0.7449 - val_loss: 0.5708 - val_accuracy: 0.7223
# Epoch 77/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5277 - accuracy: 0.7449 - val_loss: 0.5689 - val_accuracy: 0.7242
# Epoch 78/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5272 - accuracy: 0.7456 - val_loss: 0.5694 - val_accuracy: 0.7234
# Epoch 79/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5278 - accuracy: 0.7456 - val_loss: 0.5704 - val_accuracy: 0.7236
# Epoch 80/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5279 - accuracy: 0.7471 - val_loss: 0.5721 - val_accuracy: 0.7224
# Epoch 81/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5278 - accuracy: 0.7443 - val_loss: 0.5694 - val_accuracy: 0.7258
# Epoch 82/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5275 - accuracy: 0.7456 - val_loss: 0.5708 - val_accuracy: 0.7238
# Epoch 83/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5273 - accuracy: 0.7464 - val_loss: 0.5730 - val_accuracy: 0.7246
# Epoch 84/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5270 - accuracy: 0.7460 - val_loss: 0.5703 - val_accuracy: 0.7252
# Epoch 85/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5268 - accuracy: 0.7458 - val_loss: 0.5697 - val_accuracy: 0.7250
# Epoch 86/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5262 - accuracy: 0.7458 - val_loss: 0.5711 - val_accuracy: 0.7232
# Epoch 87/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5269 - accuracy: 0.7447 - val_loss: 0.5715 - val_accuracy: 0.7226
# Epoch 88/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5274 - accuracy: 0.7460 - val_loss: 0.5710 - val_accuracy: 0.7246
# Epoch 89/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5264 - accuracy: 0.7456 - val_loss: 0.5711 - val_accuracy: 0.7244
# Epoch 90/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5271 - accuracy: 0.7459 - val_loss: 0.5730 - val_accuracy: 0.7228
# Epoch 91/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5266 - accuracy: 0.7453 - val_loss: 0.5719 - val_accuracy: 0.7238
# Epoch 92/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5265 - accuracy: 0.7465 - val_loss: 0.5723 - val_accuracy: 0.7236
# Epoch 93/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5262 - accuracy: 0.7451 - val_loss: 0.5699 - val_accuracy: 0.7236
# Epoch 94/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5270 - accuracy: 0.7456 - val_loss: 0.5689 - val_accuracy: 0.7259
# Epoch 95/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5262 - accuracy: 0.7452 - val_loss: 0.5709 - val_accuracy: 0.7240
# Epoch 96/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5263 - accuracy: 0.7465 - val_loss: 0.5709 - val_accuracy: 0.7246
# Epoch 97/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5266 - accuracy: 0.7456 - val_loss: 0.5722 - val_accuracy: 0.7240
# Epoch 98/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5266 - accuracy: 0.7467 - val_loss: 0.5729 - val_accuracy: 0.7240
# Epoch 99/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5259 - accuracy: 0.7470 - val_loss: 0.5726 - val_accuracy: 0.7240
# Epoch 100/100
# 81/81 [==============================] - 0s 4ms/step - loss: 0.5259 - accuracy: 0.7466 - val_loss: 0.5737 - val_accuracy: 0.7232

# %%
# Evaluate the model using the test data
test_loss, test_mae = model.evaluate(X_test_scaled, y_test)
print("Test loss:", test_loss)
print("Test MAE:", test_mae)
# Out:
# 268/268 [==============================] - 0s 2ms/step - loss: 0.5617 - accuracy: 0.7270
# Test loss: 0.5616675615310669
# Test MAE: 0.7269970774650574

# %%
# Export our model to HDF5 file
model.save('/content/drive/MyDrive/Colab Notebooks/my_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     191       raise ValueError('Mountpoint must not be a symlink')
#     192     if _os.path.isdir(mountpoint) and _os.listdir(mountpoint):
# --> 193       raise ValueError('Mountpoint must not already contain files')
#     194     if not _os.path.isdir(mountpoint) and _os.path.exists(mountpoint):
#     195       raise ValueError('Mountpoint must either be a directory or not exist')
#
# ValueError: Mountpoint must not already contain files
